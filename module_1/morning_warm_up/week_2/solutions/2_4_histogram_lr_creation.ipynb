# %% [markdown]
# # Week 2 2.3 - linear relationships

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
# # 1. create fake data from normal distribution with 100 observations (use numpy random.normal)

x = np.random.normal(0, 1, 100)
## 2.plot a histogram to see the distribution using matplotlib
plt.hist(x)

# 3.switch to seaborn and add a smooth distribution line on top of histogram 


# 4. add titles to plots and save them in your visualizations folder

# 5. lets create now a fake linear regression data
# create weights (only one here!) and noise (give 0.1 as std for noise) from random normal as well 
# then apply y = w*x + noise
# Out:
# (array([ 6.,  5.,  7., 12., 13., 21., 11., 16.,  5.,  4.]),
#  array([-2.2482023 , -1.83494175, -1.42168119, -1.00842064, -0.59516008,
#         -0.18189952,  0.23136103,  0.64462159,  1.05788214,  1.4711427 ,
#          1.88440326]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(x)

# %%
w = np.random.normal(0, 1, 1)

noise = np.random.normal(0, 0.5 , 100)

y = x *w  + noise 

# 6. create a scatter plot of x to y
# 7. plot above the regression line

plt.scatter(x, y)
plt.plot(x, x*w, 'r--')

# 8. Calculate without any library the mean squared error 

mse = sum((y - x*w) ** 2) / len(y)

# %%
# 9. Plot the noise with respect to the predicators - this is a plot to chek 
# if the x's are independent from the errors - so for linear regression model to hold
# we need it to look like a scattered cloud 

plt.scatter(x, noise)

# %%
# 9. Push all to your github branch

# 10. [optional]create functions for the different steps in this warm-up (e.g. def x_from_standard_normal)

# 11. [optional] create a new array the same size as x and append them together 
#                 - Adjust y equation accordingly
